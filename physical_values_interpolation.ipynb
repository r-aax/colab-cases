# %% [markdown]
# <a href="https://colab.research.google.com/github/r-aax/colab-cases/blob/main/physical_values_interpolation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

def draw_graphic(data, xlabel, ylabel):
  """
  Draw graphic.
  """

  x, y = list(zip(*data))

  #xnew = np.linspace(min(x), max(x), num = 100, endpoint=True)
  fig, ax = plt.subplots(figsize=(10, 7))

  plt.rcParams['font.size'] = '16'
  for label in (ax.get_xticklabels() + ax.get_yticklabels()):
    label.set_fontsize(16)

  #plt.plot(x, y, 'o', xnew, f(xnew), '-')
  ax.plot(x, y, '-', color='silver', label='interpolated Cw', linewidth=4)
  ax.plot(x, y, 'o', color='black', label='data points', linewidth=4)
  ax.grid()

  plt.xlabel(xlabel, fontsize=20)
  plt.ylabel(ylabel, fontsize=20)

  plt.show()

# %% [markdown]
# Интерполяционные графики физических величин

# %%
# Теплоемкость воды.
c_w = [(-9, 1.019), (-8, 1.018), (-7, 1.017), (-6, 1.016), (-5, 1.015), (-4, 1.014), (-3, 1.013), (-2, 1.012), (-1, 1.011), (0, 1.01), (1, 1.009),
       (2, 1.008), (3, 1.008), (4, 1.007), (5, 1.006), (6, 1.005), (7, 1.004), (9, 1.004), (10, 1.003), (11, 1.003), (12, 1.002), (14, 1.002),
       (15, 1.001), (17, 1.001), (18, 1.0), (22, 1.0), (23, 0.999), (29, 0.999)]
draw_graphic(c_w, 'Temperature (C)', 'C_w (cal / (g * K))')

# %%
# Теплоемкость льда.
c_ice = [(-28, 0.452), (-27, 0.454), (-26, 0.455), (-25, 0.457), (-24, 0.459), (-23, 0.461), (-22, 0.463), (-21, 0.466), (-20, 0.467),
         (-19, 0.468), (-18, 0.470), (-17, 0.472), (-16, 0.474), (-15, 0.476), (-14, 0.478), (-13, 0.480), (-12, 0.481), (-11, 0.483), (-10, 0.485)]
draw_graphic(c_ice, 'Temperature (C)', 'C_ice (cal / (g * K)')

# %%
# Теплоемкость воздуха.
c_a = [(-50, 1013), (-45, 1013), (-40, 1013), (-35, 1013), (-30, 1013), (-25, 1011), (-20, 1009), (-15, 1009), (-10, 1009), (-5, 1007),
       (0, 1005), (10, 1005), (15, 1005), (20, 1005), (30, 1005), (40, 1005), (50, 1005), (60, 1005), (70, 1009), (80, 1009), (90, 1009), (100, 1009)]
draw_graphic(c_a, 'Temperature (C)', 'C_a (J / (kg * K))')

# %%
# Скрытая теплота испарения.
l_evap = [(0, 2.5), (10, 2.47), (20, 2.45), (30, 2.4), (50, 2.38), (70, 2.32), (90, 2.28), (100, 2.26), (120, 2.2), (150, 2.11), (180, 2.01),
          (200, 1.94), (220, 1.86), (250, 1.7), (300, 1.4), (350, 0.89), (370, 0.44), (374, 0.11), (374.15, 0.0)]
draw_graphic(l_evap, 'Temperature (C)', 'L_evap (MJ / kg)')

# %%
# Скрытая теплота сублимации.
l_subl = [(-39, 698.4), (-38, 697.8), (-37, 697.3), (-36, 696.8), (-35, 696.2), (-34, 695.6), (-33, 695.1), (-32, 694.5), (-31, 694.0), (-30, 693.4),
          (-29, 692.9), (-28, 692.3), (-27, 691.8), (-26, 691.2), (-25, 690.6), (-24, 690.0), (-23, 689.5), (-22, 688.9), (-21, 688.6), (-20, 688.1),
          (-19, 687.6), (-18, 687.0), (-17, 686.5), (-16, 685.9), (-15, 685.3), (-14, 684.7), (-13, 684.2), (-12, 683.6), (-11, 683.1), (-10, 682.5),
          (-9, 681.9), (-8, 681.4), (-7, 680.8), (-6, 680.3), (-5, 679.7), (-4, 679.1), (-3, 678.5), (-2, 678.0), (-1, 677.6), (0, 676.9)]
draw_graphic(l_subl, 'Temperature (C)', 'L_subl (kcal / kg)')

# %%
# Динамическая вязкость воды.
mu_w = [(0, 1.787), (5, 1.519), (10, 1.307), (20, 1.002), (30, 0.798), (40, 0.653), (50, 0.547), (60, 0.467), (70, 0.404), (80, 0.355), (90, 0.315), (100, 0.282)]
draw_graphic(mu_w, 'Temperature (C)', 'mu_w (Pa * s * 10^-3)')
